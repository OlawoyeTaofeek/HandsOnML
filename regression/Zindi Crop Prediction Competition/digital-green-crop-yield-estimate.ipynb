# %%
import os
from zipfile import ZipFile
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt    
import zipfile 
import seaborn as sns  
import warnings
warnings.filterwarnings("ignore") 
sns.set_style("darkgrid")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Omotayo\\OneDrive\\Desktop\\HandsOnML\\hands_on_ml\\regression\\Zindi Crop Prediction Competition'

# %%
os.listdir()
# Out:
# ['digital-green-crop-yield-estimate-challenge20230912-4562-1bbmstk(1).zip',
#  'digital-green-crop-yield-estimate.ipynb']

# %% [markdown]
# Extracting all the files from the zipfolders and load them into Dataframe

# %%
zip_file_path = os.path.join(os.getcwd(), os.listdir()[0])
zip_file_path
# Out:
# 'c:\\Users\\Omotayo\\OneDrive\\Desktop\\HandsOnML\\hands_on_ml\\regression\\Zindi Crop Prediction Competition\\digital-green-crop-yield-estimate-challenge20230912-4562-1bbmstk(1).zip'

# %%
# Specify the path to the zip file
zip_file_path = os.path.join(os.getcwd(), os.listdir()[0])

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract the specified file to the specified directory
    zip_ref.extractall(".")


print(f'Files extracted to: {os.getcwd()}')
# Out:
# Files extracted to: c:\Users\Omotayo\OneDrive\Desktop\HandsOnML\hands_on_ml\regression\Zindi Crop Prediction Competition

# %%
os.listdir()
# Out:
# ['digital-green-crop-yield-estimate-challenge20230912-4562-1bbmstk(1).zip',
#  'digital-green-crop-yield-estimate.ipynb',
#  'DigitalGreen_Starter_Notebook.ipynb',
#  'manifest-791977bdaaa868446d787f0618161fe720230912-4562-s64syz.json',
#  'SampleSubmission.csv',
#  'Test.csv',
#  'Train.csv',
#  'VariableDescription.csv']

# %% [markdown]
# #### Content
#
# <ul>
#     <li><a href="#inspection">Data Inspection</a></li>
#     <li><a href="#cleaning">Data Cleaning</a></li>
#     <li><a href="#engineering">Feature Engineering</a></li>
#     <li><a href="#transformation">Feature Transformation</a></li>
#     <li><a href="#target-transformation">Target Transformation</a></li>
#     <li><a href="#model-selection">Model Selection</a></li>
#     <li><a href="#optimization">Hyperparameter Optimization</a></li>
#     <li><a href="#ensemble">Ensemble Learning</a></li>
#     <li><a href="#selection">Feature Selection</a></li>
# </ul>

# %%
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", 81)

# %% [markdown]
# <!-- Section 1: Data Inspection -->
# <a id="inspection"></a>
# ### Data Inspection

# %%
# Let Load in the Train and Test set into our Dataframe 

train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
submission = pd.read_csv("SampleSubmission.csv")
VariableDescription = pd.read_csv("VariableDescription.csv")

# %%
# Aquick glance at the Descriptions
VariableDescription
# Out:
#                               Variable  \
# 0                             District
# 1                                Block
# 2                             CultLand
# 3                         CropCultLand
# 4                LandPreparationMethod
# 5                      CropTillageDate
# 6                     CropTillageDepth
# 7                        CropEstMethod
# 8                        RcNursEstDate
# 9           SeedingSowingTransplanting
# 10                     SeedlingsPerPit
# 11                       NursDetFactor
# 12                      TransDetFactor
# 13        TransplantingIrrigationHours
# 14       TransplantingIrrigationSource
# 15  TransplantingIrrigationPowerSource
# 16                       TransIrriCost
# 17                       StandingWater
# 18                      OrgFertilizers
# 19                             Ganaura
# 20                          CropOrgFYM
# 21          PCropSolidOrgFertAppMethod
# 22                   NoFertilizerAppln
# 23                      CropbasalFerts
# 24                            BasalDAP
# 25                           BasalUrea
# 26                MineralFertAppMethod
# 27                   FirstTopDressFert
# 28                             1tdUrea
# 29                        1appDaysUrea
# 30                             2tdUrea
# 31                        2appDaysUrea
# 32                MineralFertAppMethod
# 33                         Harv_method
# 34                           Harv_date
# 35                      Harv_hand_rent
# 36                      Threshing_date
# 37                    Threshing_method
# 38                      Residue_length
# 39                        Residue_perc
# 40                         Stubble_use
# 41                                Acre
# 42                               Yield
#
#                                           Description
# 0                                Name of the district
# 1                                   Name of the block
# 2                       Area of total cultivated land
# 3                      Area of land under cultivation
# 4                         Method for land preparation
# 5                 Date of tillage of the largest plot
# 6                                Depth of the tillage
# 7                           Method of transplantation
# 8                       Date of nursery establishment
# 9               Date of sowing/Transplanting the crop
# 10                           Seedling planted per pit
# 11  What are the reason of choosing the date of nu...
# 12  What are the reason for choosing the date of t...
# 13         Hours of irrigation during transplantation
# 14  Source of water for irrigation during transpla...
# 15  Source of power for irrigation pump during tra...
# 16          Cost of irrigation during transplantation
# 17  How many days of standing water was there in t...
# 18  What organic fertilizer has the farmer used du...
# 19    Amount of organic fertilizer used (in Quintals)
# 20  Amount of FYM (Farm yard manure) organic ferti...
# 21  Method of applying organic fertilizer in your ...
# 22  Number of times chemical fertilizer has been a...
# 23  Which type of chemical fertilizer has been app...
# 24  Amount of DAP(in kgs)applied during land prepa...
# 25  Amount of urea(in kgs) applied during land pre...
# 26  Method of applying chemical fertilizer in your...
# 27  Which type of chemical fertilizer has been app...
# 28  Amount of urea (in kgs) applied in the second ...
# 29  How many days after first dose was second dose...
# 30  Amount of urea (in kgs) applied in the third dose
# 31  How many days after second dose was third dose...
# 32  Method of applying chemical fertilizer in your...
# 33                               Method of harvesting
# 34                                 Date of harvesting
# 35  If labours were used or harvesting machine hir...
# 36                Date of threshing of harvested crop
# 37              Method of threshing of harvested crop
# 38        Length of the residue left after harvesting
# 39  Percentage of residue left in the field after ...
# 40  Management practice of the stubble after harve...
# 41            Area of land under cultivation in acres
# 42                          Yield of the current crop

# %%
submission.head()
# Out:
#                 ID  Yield
# 0  ID_F9XXEXN2ADR2      0
# 1  ID_SO3VW2X4QO93      0
# 2  ID_UKUQ7JM8E894      0
# 3  ID_QUISMWEZR2H4      0
# 4  ID_25JGI455VKCZ      0

# %% [markdown]
# Now lets look at our actual Datasets

# %%
train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
#
#   SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                 2022-07-21              2.0
# 1                 2022-07-20              2.0
# 2                 2022-08-13              2.0
# 3                 2022-07-17              2.0
# 4                 2022-07-20              2.0
#
#                                        NursDetFactor  \
# 0  CalendarDate IrrigWaterAvailability SeedAvaila...
# 1  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 2  PreMonsoonShowers IrrigWaterAvailability Labou...
# 3  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 4  CalendarDate IrrigWaterAvailability SeedAvaila...
#
#                                       TransDetFactor  \
# 0  CalendarDate SeedlingAge RainArrival IrrigWate...
# 1  CalendarDate SeedlingAge RainArrival IrrigWate...
# 2  SeedlingAge IrrigWaterAvailability LaborAvaila...
# 3  CalendarDate SeedlingAge RainArrival IrrigWate...
# 4  SeedlingAge RainArrival IrrigWaterAvailability...
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           NaN                           NaN
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                           Electric          200.0            2.0
# 1                           Electric          125.0            3.0
# 2                           Electric           80.0            2.0
# 3                                NaN            NaN            NaN
# 4                           Electric          300.0            2.0
#
#   OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0            NaN      NaN         NaN                        NaN
# 1            NaN      NaN         NaN                        NaN
# 2    Ganaura FYM      1.0         1.0                SoilApplied
# 3        Ganaura      1.0         NaN                SoilApplied
# 4            NaN      NaN         NaN                        NaN
#
#    NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea MineralFertAppMethod  \
# 0                  2           Urea       NaN       20.0         Broadcasting
# 1                  2       DAP Urea      15.0       10.0         Broadcasting
# 2                  2            DAP       4.0        NaN          SoilApplied
# 3                  2       DAP Urea       6.0        3.0         Broadcasting
# 4                  2       Urea DAP      15.0       30.0         Broadcasting
#
#   FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  2appDaysUrea  \
# 0              Urea     15.0          18.0      NaN           NaN
# 1              Urea     20.0          39.0      NaN           NaN
# 2              Urea      5.0          65.0      NaN           NaN
# 3              Urea      5.0           5.0      NaN           NaN
# 4              Urea     30.0          26.0      NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             NaN
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             NaN
#
#   Threshing_date Threshing_method  Residue_length  Residue_perc  \
# 0     2022-11-16          machine              30            40
# 1     2022-12-24          machine              24            10
# 2     2023-01-11          machine              30            10
# 3     2022-12-29             hand              26            10
# 4     2022-12-02          machine              24            40
#
#       Stubble_use      Acre  Yield
# 0  plowed_in_soil  0.312500    600
# 1  plowed_in_soil  0.312500    600
# 2  plowed_in_soil  0.148148    225
# 3  plowed_in_soil  0.222222    468
# 4  plowed_in_soil  0.468750    550

# %%
train.shape
# Out:
# (3870, 44)

# %%
test.head()
# Out:
#                 ID  District   Block  CultLand  CropCultLand  \
# 0  ID_F9XXEXN2ADR2     Jamui  Khaira        20            13
# 1  ID_SO3VW2X4QO93     Jamui  Khaira        25            25
# 2  ID_UKUQ7JM8E894   Nalanda  Rajgir        30            30
# 3  ID_QUISMWEZR2H4  Vaishali   Mahua        15            10
# 4  ID_25JGI455VKCZ   Nalanda  Rajgir        30            10
#
#                                LandPreparationMethod CropTillageDate  \
# 0                                      TractorPlough      2022-07-24
# 1                                      TractorPlough      2022-07-24
# 2  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 3  WetTillagePuddling TractorPlough BullockPlough...      2022-07-04
# 4  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-21
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 4    Manual_PuddledLine    2022-07-03
# 1                 5  Manual_PuddledRandom    2022-07-08
# 2                 5  Manual_PuddledRandom    2022-06-24
# 3                 5  Manual_PuddledRandom    2022-06-20
# 4                 3  Manual_PuddledRandom    2022-06-24
#
#   SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                 2022-07-29              1.0
# 1                 2022-08-02              4.0
# 2                 2022-07-08              2.0
# 3                 2022-07-10              2.0
# 4                 2022-07-22              1.0
#
#                                        NursDetFactor  \
# 0  LabourAvailability IrrigWaterAvailability PreM...
# 1  CalendarDate SeedAvailability IrrigWaterAvaila...
# 2  PreMonsoonShowers IrrigWaterAvailability Labou...
# 3  CalendarDate IrrigWaterAvailability LabourAvai...
# 4            SeedAvailability IrrigWaterAvailability
#
#                                       TransDetFactor  \
# 0  IrrigWaterAvailability LaborAvailability RainA...
# 1  CalendarDate SeedlingAge IrrigWaterAvailabilit...
# 2  SeedlingAge RainArrival IrrigWaterAvailability...
# 3  CalendarDate SeedlingAge RainArrival IrrigWate...
# 4  SeedlingAge IrrigWaterAvailability LaborAvaila...
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           2.0                        Boring
# 1                           2.0                         Canal
# 2                           4.0                         Canal
# 3                           2.0                        Boring
# 4                           6.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                             Diesel          200.0            2.0
# 1                                NaN            NaN            3.0
# 2                                NaN            NaN           10.0
# 3                             Diesel            NaN            NaN
# 4                           Electric          400.0            NaN
#
#   OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0            FYM      NaN         2.0                SoilApplied
# 1            NaN      NaN         NaN                        NaN
# 2        Ganaura      2.0         NaN               Broadcasting
# 3            FYM      NaN         5.0                SoilApplied
# 4            NaN      NaN         NaN                        NaN
#
#    NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea MineralFertAppMethod  \
# 0                  3            DAP       6.0        NaN         Broadcasting
# 1                  3            DAP       5.0        NaN         Broadcasting
# 2                  2       DAP Urea       9.0       18.0         Broadcasting
# 3                  2            DAP      15.0        NaN          SoilApplied
# 4                  2       DAP Urea      20.0       15.0         Broadcasting
#
#   FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  2appDaysUrea  \
# 0              Urea      8.0          23.0      6.0          63.0
# 1              Urea      7.0          23.0      8.0          65.0
# 2              Urea      9.0          38.0      NaN           NaN
# 3              Urea      9.0          30.0      NaN           NaN
# 4              Urea     15.0          40.0      NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting        hand  2022-12-02           500.0
# 1           Broadcasting        hand  2022-11-12           150.0
# 2           Broadcasting        hand  2022-11-24          1200.0
# 3            SoilApplied        hand  2022-10-15           300.0
# 4           Broadcasting     machine  2022-11-20             NaN
#
#   Threshing_date Threshing_method  Residue_length  Residue_perc  \
# 0     2022-12-28             hand              22            10
# 1     2022-12-20          machine              28            10
# 2     2022-12-05          machine              28            10
# 3     2022-10-25             hand              30            10
# 4     2022-11-20          machine              26            40
#
#       Stubble_use      Acre
# 0  plowed_in_soil  0.272727
# 1  plowed_in_soil  0.227273
# 2  plowed_in_soil  0.281250
# 3  plowed_in_soil  0.136364
# 4  plowed_in_soil  0.312500

# %%
test.shape
# Out:
# (1290, 43)

# %%
# Checking for Null values
train.isnull().sum()
# Out:
# ID                                       0
# District                                 0
# Block                                    0
# CultLand                                 0
# CropCultLand                             0
# LandPreparationMethod                    0
# CropTillageDate                          0
# CropTillageDepth                         0
# CropEstMethod                            0
# RcNursEstDate                           83
# SeedingSowingTransplanting               0
# SeedlingsPerPit                        289
# NursDetFactor                          289
# TransDetFactor                         289
# TransplantingIrrigationHours           193
# TransplantingIrrigationSource          115
# TransplantingIrrigationPowerSource     503
# TransIrriCost                          882
# StandingWater                          238
# OrgFertilizers                        1335
# Ganaura                               2417
# CropOrgFYM                            2674
# PCropSolidOrgFertAppMethod            1337
# NoFertilizerAppln                        0
# CropbasalFerts                         188
# BasalDAP                               543
# BasalUrea                             1704
# MineralFertAppMethod                     0
# FirstTopDressFert                      485
# 1tdUrea                                556
# 1appDaysUrea                           556
# 2tdUrea                               2694
# 2appDaysUrea                          2700
# MineralFertAppMethod.1                 481
# Harv_method                              0
# Harv_date                                0
# Harv_hand_rent                         252
# Threshing_date                           0
# Threshing_method                         0
# Residue_length                           0
# Residue_perc                             0
# Stubble_use                              0
# Acre                                     0
# Yield                                    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# ID                                      0
# District                                0
# Block                                   0
# CultLand                                0
# CropCultLand                            0
# LandPreparationMethod                   0
# CropTillageDate                         0
# CropTillageDepth                        0
# CropEstMethod                           0
# RcNursEstDate                          43
# SeedingSowingTransplanting              0
# SeedlingsPerPit                       103
# NursDetFactor                         103
# TransDetFactor                        103
# TransplantingIrrigationHours           77
# TransplantingIrrigationSource          46
# TransplantingIrrigationPowerSource    171
# TransIrriCost                         317
# StandingWater                          79
# OrgFertilizers                        415
# Ganaura                               795
# CropOrgFYM                            868
# PCropSolidOrgFertAppMethod            416
# NoFertilizerAppln                       0
# CropbasalFerts                         76
# BasalDAP                              191
# BasalUrea                             571
# MineralFertAppMethod                    0
# FirstTopDressFert                     149
# 1tdUrea                               177
# 1appDaysUrea                          178
# 2tdUrea                               875
# 2appDaysUrea                          882
# MineralFertAppMethod.1                146
# Harv_method                             0
# Harv_date                               0
# Harv_hand_rent                         73
# Threshing_date                          0
# Threshing_method                        0
# Residue_length                          0
# Residue_perc                            0
# Stubble_use                             0
# Acre                                    0
# dtype: int64

# %%
# Check for Duplicates

train.duplicated().sum()
# Out:
# 0

# %%
# Check for Duplicates

test.duplicated().sum()
# Out:
# 0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 44 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  3870 non-null   object
#  1   District                            3870 non-null   object
#  2   Block                               3870 non-null   object
#  3   CultLand                            3870 non-null   int64
#  4   CropCultLand                        3870 non-null   int64
#  5   LandPreparationMethod               3870 non-null   object
#  6   CropTillageDate                     3870 non-null   object
#  7   CropTillageDepth                    3870 non-null   int64
#  8   CropEstMethod                       3870 non-null   object
#  9   RcNursEstDate                       3787 non-null   object
#  10  SeedingSowingTransplanting          3870 non-null   object
#  11  SeedlingsPerPit                     3581 non-null   float64
#  12  NursDetFactor                       3581 non-null   object
#  13  TransDetFactor                      3581 non-null   object
#  14  TransplantingIrrigationHours        3677 non-null   float64
#  15  TransplantingIrrigationSource       3755 non-null   object
#  16  TransplantingIrrigationPowerSource  3367 non-null   object
#  17  TransIrriCost                       2988 non-null   float64
#  18  StandingWater                       3632 non-null   float64
#  19  OrgFertilizers                      2535 non-null   object
#  20  Ganaura                             1453 non-null   float64
#  21  CropOrgFYM                          1196 non-null   float64
#  22  PCropSolidOrgFertAppMethod          2533 non-null   object
#  23  NoFertilizerAppln                   3870 non-null   int64
#  24  CropbasalFerts                      3682 non-null   object
#  25  BasalDAP                            3327 non-null   float64
#  26  BasalUrea                           2166 non-null   float64
#  27  MineralFertAppMethod                3870 non-null   object
#  28  FirstTopDressFert                   3385 non-null   object
#  29  1tdUrea                             3314 non-null   float64
#  30  1appDaysUrea                        3314 non-null   float64
#  31  2tdUrea                             1176 non-null   float64
#  32  2appDaysUrea                        1170 non-null   float64
#  33  MineralFertAppMethod.1              3389 non-null   object
#  34  Harv_method                         3870 non-null   object
#  35  Harv_date                           3870 non-null   object
#  36  Harv_hand_rent                      3618 non-null   float64
#  37  Threshing_date                      3870 non-null   object
#  38  Threshing_method                    3870 non-null   object
#  39  Residue_length                      3870 non-null   int64
#  40  Residue_perc                        3870 non-null   int64
#  41  Stubble_use                         3870 non-null   object
#  42  Acre                                3870 non-null   float64
#  43  Yield                               3870 non-null   int64
# dtypes: float64(14), int64(7), object(23)
# memory usage: 1.3+ MB

# %% [markdown]
# <!-- Section 2: Data Cleaning -->
# <a id="cleaning"></a>
# ## Data Cleaning

# %%
data = [train, test]
for set_ in data:
    set_.drop(columns=['ID'], axis="columns", inplace=True)

# %%
train.shape
# Out:
# (3870, 43)

# %%
test.shape
# Out:
# (1290, 42)
